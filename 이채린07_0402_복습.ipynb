# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaelinL/DataAnalysis_Study/blob/main/%EC%9D%B4%EC%B1%84%EB%A6%B007_0402_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터분석 기초반 5주차 수업
# - 데이터프레임과 시리즈에 대한 이해
# - 시각화 초반

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **데이터프레임과 시리즈가 어떤 식으로 작동하고 다른 것인가?**

# %%
# mpg 데이터 불러오기
from google.colab import drive
drive.mount('/content/drive')

mpg = pd.read_csv('/content/drive/My Drive/mpg.csv')
mpg  # 컬럼이 2개 이상이기 때문에 데이터프레임 형태이다.
# Out:
# Mounted at /content/drive
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# ...

# %% [markdown]
# - 시리즈 만들기

# %%
a = pd.Series(['홍길동', 15])
a  # 인덱스가 없는 경우 디폴트가 0, 1
# Out:
# 0    홍길동
# 1     15
# dtype: object

# %%
a = pd.Series(['홍길동', 15], index=['name', 'age'])  # 인덱스가 필요한 경우 선언 가능
a
# Out:
# name    홍길동
# age      15
# dtype: object

# %% [markdown]
# - 데이터프레임 만들기

# %%
st = pd.DataFrame({'name':['홍길동','김영희'],
                   'age':[15,18]},
                  index = ['1반','2반'])
st
# Out:
#    name  age
# 1반  홍길동   15
# 2반  김영희   18

# %% [markdown]
# - 시리즈를 살펴보자

# %%
a.index  # 인덱스만 추출하는 것도 가능하다.
# Out:
# Index(['name', 'age'], dtype='object')

# %%
a.values
# Out:
# array(['홍길동', 15], dtype=object)

# %%
a.keys()  # 키값을 갖고 온다.
# Out:
# Index(['name', 'age'], dtype='object')

# %% [markdown]
# - 데이터프레임을 시리즈 형태로 볼 수 있다.

# %%
mpg_sp = mpg['model']
mpg['model'].drop_duplicates()
# Out:
# 0                          a4
# 7                  a4 quattro
# 15                 a6 quattro
# 18         c1500 suburban 2wd
# 23                   corvette
# 28            k1500 tahoe 4wd
# 32                     malibu
# 37                caravan 2wd
# 48          dakota pickup 4wd
# 57                durango 4wd
# 64        ram 1500 pickup 4wd
# 74             expedition 2wd
# 77               explorer 4wd
# 83            f150 pickup 4wd
# 90                    mustang
# 99                      civic
# 108                    sonata
# 115                   tiburon
# 122        grand cherokee 4wd
# 130               range rover
# 134             navigator 2wd
# 137           mountaineer 4wd
# 141                    altima
# 147                    maxima
# 150            pathfinder 4wd
# 154                grand prix
# 159              forester awd
# 165               impreza awd
# 173               4runner 4wd
# 179                     camry
# 186              camry solara
# ...

# %%
mpg_sp.values  # 배열 형태로 만들어진다.
# Out:
# array(['a4', 'a4', 'a4', 'a4', 'a4', 'a4', 'a4', 'a4 quattro',
#        'a4 quattro', 'a4 quattro', 'a4 quattro', 'a4 quattro',
#        'a4 quattro', 'a4 quattro', 'a4 quattro', 'a6 quattro',
#        'a6 quattro', 'a6 quattro', 'c1500 suburban 2wd',
#        'c1500 suburban 2wd', 'c1500 suburban 2wd', 'c1500 suburban 2wd',
#        'c1500 suburban 2wd', 'corvette', 'corvette', 'corvette',
#        'corvette', 'corvette', 'k1500 tahoe 4wd', 'k1500 tahoe 4wd',
#        'k1500 tahoe 4wd', 'k1500 tahoe 4wd', 'malibu', 'malibu', 'malibu',
#        'malibu', 'malibu', 'caravan 2wd', 'caravan 2wd', 'caravan 2wd',
#        'caravan 2wd', 'caravan 2wd', 'caravan 2wd', 'caravan 2wd',
#        'caravan 2wd', 'caravan 2wd', 'caravan 2wd', 'caravan 2wd',
#        'dakota pickup 4wd', 'dakota pickup 4wd', 'dakota pickup 4wd',
#        'dakota pickup 4wd', 'dakota pickup 4wd', 'dakota pickup 4wd',
#        'dakota pickup 4wd', 'dakota pickup 4wd', 'dakota pickup 4wd',
# ...

# %%
mpg_sp_lt = list(mpg_sp.values)  # 리스트 형태로 만들어진다.
mpg_sp_lt
# Out:
# ['a4',
#  'a4',
#  'a4',
#  'a4',
#  'a4',
#  'a4',
#  'a4',
#  'a4 quattro',
#  'a4 quattro',
#  'a4 quattro',
#  'a4 quattro',
#  'a4 quattro',
#  'a4 quattro',
#  'a4 quattro',
#  'a4 quattro',
#  'a6 quattro',
#  'a6 quattro',
#  'a6 quattro',
#  'c1500 suburban 2wd',
#  'c1500 suburban 2wd',
#  'c1500 suburban 2wd',
#  'c1500 suburban 2wd',
#  'c1500 suburban 2wd',
#  'corvette',
#  'corvette',
#  'corvette',
#  'corvette',
#  'corvette',
#  'k1500 tahoe 4wd',
#  'k1500 tahoe 4wd',
#  'k1500 tahoe 4wd',
#  'k1500 tahoe 4wd',
#  'malibu',
#  'malibu',
#  'malibu',
#  'malibu',
#  'malibu',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'caravan 2wd',
#  'dakota pickup 4wd',
#  'dakota pickup 4wd',
#  'dakota pickup 4wd',
#  'dakota pickup 4wd',
#  'dakota pickup 4wd',
#  'dakota pickup 4wd',
#  'dakota pickup 4wd',
#  'dakota pickup 4wd',
# ...

# %%
# for문을 사용해 값만 추출하는 것이 가능하다.
for i in mpg_sp_lt:
  print(i)
# Out:
# a4
# a4
# a4
# a4
# a4
# a4
# a4
# a4 quattro
# a4 quattro
# a4 quattro
# a4 quattro
# a4 quattro
# a4 quattro
# a4 quattro
# a4 quattro
# a6 quattro
# a6 quattro
# a6 quattro
# c1500 suburban 2wd
# c1500 suburban 2wd
# c1500 suburban 2wd
# c1500 suburban 2wd
# c1500 suburban 2wd
# corvette
# corvette
# corvette
# corvette
# corvette
# k1500 tahoe 4wd
# k1500 tahoe 4wd
# k1500 tahoe 4wd
# k1500 tahoe 4wd
# malibu
# malibu
# malibu
# malibu
# malibu
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# caravan 2wd
# dakota pickup 4wd
# dakota pickup 4wd
# dakota pickup 4wd
# dakota pickup 4wd
# dakota pickup 4wd
# dakota pickup 4wd
# dakota pickup 4wd
# dakota pickup 4wd
# dakota pickup 4wd
# durango 4wd
# durango 4wd
# durango 4wd
# durango 4wd
# durango 4wd
# durango 4wd
# durango 4wd
# ram 1500 pickup 4wd
# ram 1500 pickup 4wd
# ram 1500 pickup 4wd
# ram 1500 pickup 4wd
# ram 1500 pickup 4wd
# ...

# %% [markdown]
# **시리즈의 연산**
# - 시리즈는 다양한 연산이 가능하다.
# - 데이터프레임은 바로 값을 계산하는데 한계가 있는데 시리즈로 하게 되면 자유자재로 배열로 계산이 가능하다.

# %%
mpg.cty.mean()
# Out:
# 16.858974358974358

# %%
mpg.cty.mean()*mpg.hwy.mean()  # 이처럼 간편하게 코드 한 줄로 연산이 가능하다.
# Out:
# 395.17724085031773

# %%
mpg.cty + mpg.cty
# Out:
# 0      36
# 1      42
# 2      40
# 3      42
# 4      32
#        ..
# 229    38
# 230    42
# 231    32
# 232    36
# 233    34
# Name: cty, Length: 234, dtype: int64

# %% [markdown]
# **데이터프레임**
# - 참 거짓을 통해서 값을 추출할 수 있다.

# %%
mpg[mpg['cty']>mpg['cty'].mean()]  # 참이 되는 값만 추출한다.
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6  manual(m5)   f   18   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 228   volkswagen  passat    1.8  1999    4    auto(l5)   f   18   29  p
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.cty.dtype  # 데이터 타입을 확인할 수 있다.
# Out:
# dtype('int64')

# %% [markdown]
# - 컬럼만 추출하고 싶은 경우

# %%
mpg.columns  # 컬럼만 추출할 수 있다.
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'category'],
#       dtype='object')

# %%
a = list(mpg.columns)  # 리스트 형태로 컬럼을 추출할 수도 있다.

for i in a:
  print(mpg[i])  # for문을 사용해 모든 컬럼을 차례대로 추출할 수 있다.
# Out:
# 0            audi
# 1            audi
# 2            audi
# 3            audi
# 4            audi
#           ...
# 229    volkswagen
# 230    volkswagen
# 231    volkswagen
# 232    volkswagen
# 233    volkswagen
# Name: manufacturer, Length: 234, dtype: object
# 0          a4
# 1          a4
# 2          a4
# 3          a4
# 4          a4
#         ...
# 229    passat
# 230    passat
# 231    passat
# 232    passat
# 233    passat
# Name: model, Length: 234, dtype: object
# 0      1.8
# 1      1.8
# 2      2.0
# 3      2.0
# 4      2.8
#       ...
# 229    2.0
# 230    2.0
# 231    2.8
# 232    2.8
# 233    3.6
# Name: displ, Length: 234, dtype: float64
# 0      1999
# 1      1999
# 2      2008
# 3      2008
# 4      1999
#        ...
# 229    2008
# 230    2008
# 231    1999
# 232    1999
# 233    2008
# Name: year, Length: 234, dtype: int64
# 0      4
# 1      4
# 2      4
# 3      4
# 4      6
#       ..
# 229    4
# 230    4
# 231    6
# 232    6
# 233    6
# ...

# %% [markdown]
# **시각화 진행하기**
# - 시각화를 하는 이유: 패턴을 찾고, 경향을 보고 설명하기 위함.
# - 데이터 분석가가 분석을 하고 그 분석에 대한 근거를 제시하기 위해 데이터 분석을 잘 모르는 사람들에게 시각화를 통해 더욱 쉽고 빠르게 이해시키기 위함.
# - 데이터 타입에 따라 시각화를 다르게 하는 것이 중요!

# %% [markdown]
# **시각화에 필요한 대표적인 라이브러리**
# - matplotlib, seaborn

# %%
import matplotlib.pyplot as plt

# %%
# 산점도를 그려보자
plt.scatter([1,2,3],[4,5,6])
plt.show()

# %%
# 두 개 이상을 그리면 자동으로 합쳐진다.
plt.scatter([1,2,3],[4,5,6])
plt.scatter([5,6,7],[10,5,6])
plt.scatter([2,4,8],[1,2,5])
plt.show()

# %% [markdown]
# **그래프의 축과 이름을 설정해보기!**

# %%
plt.scatter([1,2,3],[4,5,6])
plt.title('mpg')  # 그래프 제목
plt.xlabel('mpg.hwy')  # x축 제목
plt.ylabel('mpg.cty')  # y축 제목목
# Out:
# Text(0, 0.5, 'mpg.cty')

# %% [markdown]
# **축의 범위 설정**
# - xlim, ylim을 이용해 축의 범위를 설정할 수 있다.

# %%
plt.scatter([1,2,3],[4,5,6])
plt.xlim(0,200)
plt.ylim(30,50)
# Out:
# (30.0, 50.0)

# %% [markdown]
# **눈금값 조절**
# - xticks, yticks

# %%
plt.scatter([1,2,3],[4,5,6])
plt.xticks([1,2,3],['A','B','C'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f1760959670>,
# ...
#  [Text(1, 0, 'A'), Text(2, 0, 'B'), Text(3, 0, 'C')])

# %% [markdown]
# **범례 설정**
# - legend() 함수를 이용해서 label 범례를 출력한다.

# %%
plt.scatter([1,2,3],[4,5,6], label='mpg.cty')
plt.scatter([6,7,8],[3,2,5], label='mpg.hwy')
plt.legend()

# %% [markdown]
# - legend(loc='')을 통해 범례의 위치를 조절할 수 있다.

# %%
plt.scatter([1,2,3],[4,5,6], label='mpg.cty')
plt.scatter([6,7,8],[3,2,5], label='mpg.hwy')
plt.legend(loc='center')

# %% [markdown]
# **그래프 크기 조절**
# - figure 함수를 사용해 figsize 도화지의 크기를 만들어준다. (x=10, y=5)

# %%
plt.figure(figsize=(10,5))
plt.scatter([1,2,3],[4,5,6], label='mpg.cty')

# %% [markdown]
# - matplotlib와 같이 seaborn으로도 동일한 그래프를 만들 수 있다.

# %%
import seaborn as sns

# %%
sns.set()  # 기본값이 grid
plt.scatter([1,2,3],[4,5,6])

# %%
sns.set(style='whitegrid') # style=''을 통해 배경색을 바꿀 수 있다.
plt.scatter([1,2,3],[4,5,6])

# %%
sns.set(style='dark')
plt.scatter([1,2,3],[4,5,6])

# %% [markdown]
# **다양한 그래프를 그려보자!**
# - 선그래프 그려보기
# - plot 함수를 이용해서 그래프를 그린다.
# - x와 y 좌표는 수치형 데이터

# %%
sns.set(style='whitegrid')
plt.plot([1,2,3],[4,5,6], label='mpg.cty')
plt.plot([6,7,8],[3,2,5], label='mpg.hwy')
plt.legend()

# %% [markdown]
# **다양한 색상 설정**
# - color=''를 통해 black, gray, yellow, navy 등 다양한 색상 설정 가능

# %%
sns.set(style = 'whitegrid')
plt.plot([1,2,3],[4,5,6],label='mpg.cty',color='red')
plt.plot([6,7,8],[3,2,5],label='mpg.hwy',color='blue')
plt.legend()

# %% [markdown]
# **선 스타일과 두께 설정**
# - 선 형태 기본값에 linestyle=''을 사용해 dashed, dotted, dashdot, solid 등 스타일을 설정할 수 있다.
# - linewidth=을 사용해 선 두께를 조절할 수 있다.

# %%
sns.set(style = 'whitegrid')
plt.plot([1,2,3],[4,5,6],label='mpg.cty',color='red',linestyle='dashed', linewidth=10)
plt.plot([6,7,8],[3,2,5],label='mpg.hwy',color='blue',linestyle='dotted', linewidth=5)
plt.legend()

# %% [markdown]
# **마커 설정**
# - 값에 대한 포인트를 지정해서 해당 값이 어디에 위치하는지 찍어줄 수 있다.
# - '.' => 점, 'o' => 원, '*' => 별

# %%
plt.plot([1,2,3],[4,5,6],marker='s',label='mpg.cty',color='red',linestyle='dashed')
plt.plot([6,7,8],[3,2,5],marker='*',label='mpg.hwy',color='blue',linestyle='dotted')
plt.legend()

# %%
# markersize를 통해 마커 크기도 조절 가능하다.
plt.plot([1,2,3],[4,5,6],marker='s',markersize=10,label='mpg.cty',color='red',linestyle='dashed')
plt.plot([6,7,8],[3,2,5],marker='*',label='mpg.hwy',color='blue',linestyle='dotted')
plt.legend()

# %% [markdown]
# **투명도 설정**
# - alpha를 통해 값들의 투명도를 설정할 수 있다.

# %%
x = np.random.normal(0,1,5000)
y = np.random.normal(0,1,5000)

plt.scatter(x,y, alpha=0.05)

# %%
plt.scatter(x,y, alpha=0.5)
